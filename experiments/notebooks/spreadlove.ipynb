# %%
import os
import urllib
import datetime
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
posts = pd.read_csv(os.path.join(Path.home(), 'socialdata', 'fbaccount', 'spruechetante', 'fetch0', 'posts.csv'))
posts
# Out:
#                post_id                                               text  \
# 0     5294648420587173  Und plötzlich hörst du dieses eine Lied, bekom...
# 1     5456875504364463  Euch allen ein schönes Pfingstwochenende ☀️\n\...
# 2     5454598561258824  Viele warten auf ihren Glückstag, aber das Glü...
# 3     5434895806562433  Je älter ich werde, desto weniger Zeit habe ic...
# 4     5411175575601123  Liebe ist, wenn jemand deine Welt auf den Kopf...
# ...                ...                                                ...
# 7045   752437228141671                                                NaN
# 7046   752420371476690                                                NaN
# 7047   752376234814437                                                NaN
# 7048   752058024846258                                                NaN
# 7049   751963528189041                                                NaN
#
#                                               post_text shared_text  \
# ...

# %%
posts['text'].unique()
# Out:
# array(['Und plötzlich hörst du dieses eine Lied, bekommst Gänsehaut und die Welt steht für einen Augenblick still.\n\n#musik #gänsehaut #erinnerungen #spruchdestages #sprüchetante',
#        'Euch allen ein schönes Pfingstwochenende ☀️\n\n#schönepfingsten #pfingsten #pfingstwochenende #grüße #s#sprüchetante',
#        'Viele warten auf ihren Glückstag, aber das Glück steckt in jedem einzelnen Tag.\n\n#glückstag #glück #spruchdestages #zitateundsprüche #sprüchetante',
#        ...,
#        'Und da ist er wieder der Montag ... Euch allen einen guten Start in die neue Woche\n\nYOUTUBE.COM\nMontag',
#        '!\n\nErwachsenwerden? Ich mach ja viel Scheiß mit, aber nicht jeden is with Jacqueline Amthor.\n28. März 2014 um 12:36 ·',
#        'Erwachsenwerden? Ich mach ja viel Scheiß mit, aber nicht jeden\n25. März 2014 um 17:30 ·'],
#       dtype=object)

# %%
posts['text'].fillna('', inplace=True)
posts.iloc[posts['likes'].argmax()]
# Out:
# post_id                                                           1118798741505516
# text
# post_text                                                                      NaN
# shared_text                                                                    NaN
# original_text                                                                  NaN
# time                                                           2015-12-31 10:49:55
# timestamp                                                               1451555395
# image                                                                          NaN
# image_lowquality                 https://scontent.flnz1-1.fna.fbcdn.net/v/t1.18...
# images                                                                         NaN
# images_description                                                             NaN
# images_lowquality                ['https://scontent.flnz1-1.fna.fbcdn.net/v/t1....
# ...

# %%
posts[posts['text'].apply(lambda x: x.find('liebe') != -1)]
# Out:
#                post_id                                               text  \
# 4     5411175575601123  Liebe ist, wenn jemand deine Welt auf den Kopf...
# 35    5187163471335669  Das Leben ist vergänglich, doch die Liebe, Ach...
# 42    5150741291644554  "Du bist mir wichtig."\nWenig Worte.\nViel Bed...
# 75    4904841152901237  Wer mit den Augen liebt,\nliebt nur einen Auge...
# 102   4738265422892145  Und heute Nacht schlafe ich ein,\nmit dir in m...
# ...                ...                                                ...
# 6065   959174080801317  „Ich will dir ein Hund für eine Weile leihen“,...
# 6229   909930935725632  Bob Marley über die Liebe\n\n“Du wirst viellei...
# 6392   870014269717299  Solange ich noch stehen kann, #kämpfe ich für ...
# 6393   870092756376117  Nehmen, was ich kriegen kann, ohne Rücksicht a...
# 6943   765346950184032  Hey Du !!! ... Ja Du !!!\nHör auf unglücklich ...
#
#                                               post_text   shared_text  \
# ...
